# %%
str = "asdf sdfsdf"

# %%
len(str)
str = list(str)

# %%
str
# Out:
# ['a', 's', 'd', 'f', ' ', 's', 'd', 'f', 's', 'd', 'f']

# %%
for i in str:
    print(i)
# Out:
# a
# s
# d
# f
#
# s
# d
# f
# s
# d
# f

# %%
from collections import Counter
cnt = Counter(str)

# %%
cnt
# Out:
# Counter({'s': 3, 'd': 3, 'f': 3, 'a': 1, ' ': 1})
